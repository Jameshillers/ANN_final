# %%
#loading packages
import pandas as pd
import matplotlib as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# reading the csv and checking it loads properly
df = pd.read_csv("data.csv")


df.columns = ["journal", "afraid", "angry", "anxious", "ashamed", "awkward", "bored", 
              "calm", "confused", "disgusted", "excited", "frustrated", "happy", "jealous", 
              "nostalgic", "proud", "sad", "satisfied", "surprised", "exercise", "family", 
              "food", "friends", "god", "health", "love", "recreation", "school", "sleep", "work"]
print(df.columns)
df.head(1)
# Out:
# Index(['journal', 'afraid', 'angry', 'anxious', 'ashamed', 'awkward', 'bored',
#        'calm', 'confused', 'disgusted', 'excited', 'frustrated', 'happy',
#        'jealous', 'nostalgic', 'proud', 'sad', 'satisfied', 'surprised',
#        'exercise', 'family', 'food', 'friends', 'god', 'health', 'love',
#        'recreation', 'school', 'sleep', 'work'],
#       dtype='object')
#                                              journal  afraid  angry  anxious  \
# 0  My family was the most salient part of my day,...   False  False     True
#
#    ashamed  awkward  bored   calm  confused  disgusted  ...  family   food  \
# 0    False    False  False  False     False      False  ...    True  False
#
#    friends    god  health   love  recreation  school  sleep   work
# 0    False  False   False  False       False   False  False  False
#
# [1 rows x 30 columns]
